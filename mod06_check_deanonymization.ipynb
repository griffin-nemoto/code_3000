# %%
import pandas as pd
from mod06_deanonymize import load_data, link_records, deanonymization_rate

# %%
anon_path = "mod06_data/anonymized.csv"
aux_path = "mod06_data/auxiliary.csv"

# %% [markdown]
# ### Load and review the data

# %%
anon, aux = load_data(anon_path, aux_path)

# %%
anon.head(20)
# Out:
#    anon_id  age  zip3 gender
# 0    ERM5C   50   432      F
# 1    OFJJP   75   323      F
# 2    I3H24   44   323      M
# 3    3WUYW   66   323      M
# 4    ZN91P   18   323      M
# 5    7BLKV   36   606      F
# 6    4SJFH   70   890      M
# 7    0NO3L   31   110      M
# 8    U060Z   80   191      F
# 9    1761H   58   606      M
# 10   I9UI2   53   432      M
# 11   OO0ZT   47   941      F
# 12   BPEI7   19   112      M
# 13   ULMOZ   47   110      M
# 14   ES0E7   75   323      F
# 15   XCR1D   73   606      M
# 16   AY6JA   69   323      M
# 17   Q1J6V   40   941      F
# 18   BU6DU   54    62      F
# 19   LL1K7   69    21      M

# %% [markdown]
# ### Merge the datasets by age, gender, and zip3 and return the unique matches

# %%
matches = link_records(anon, aux)
matches.head()
# Out:
#     anon_id   matched_name
# 7     ZN91P  Kyle Martinez
# 32    LL1K7   Omar Jackson
# 76    8J8S0      Alice Lee
# 95    T9W97  Viola Jackson
# 160   D4J2J   Julia Garcia

# %% [markdown]
# ### Calculate the match rate

# %%
rate = deanonymization_rate(matches, anon)
print(rate)
# Out:
# 0.038

# %% [markdown]
# # Discussion Questions

# %% [markdown]
# ### Describe your reaction to the match rate. What sources of data might be prone to privacy issues?

# %% [markdown]
# The match rate is pretty low with only around 4%, but considering that you're only using very basic variables it's not terrible. These are things commonly asked in many kinds of surveys but also very accessible online like on social media accounts which makes them easy to track back to you.

# %% [markdown]
# ### Provide examples of at least two other variables that could increase the match rate if included.

# %% [markdown]
# Date of birth and home address would essentially be more exact versions of age and zip code so it would definitely be more effective and increase the match rate. Otherwise using car insurance as an example like in class, car make and model or something like credit score is something that companies have access to that could be used in conjunction with others to trace back to you.
